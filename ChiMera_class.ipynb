# %% [markdown]
# # 🦠 Building your own Genome Scale Model with ChiMera
#
#
# <img src="input_examples/assets/ChiMera_logo.png" alt="ChiMera logo" style="height: 200px; width:200px;margin-left: 330px;"/>
#
#
#
#
# This notebook will teach the basics of ChiMera.
#
# ## About the Install and Data
#
# The folder `input_examples` will have all necessary data to perform the Tutorial!
#
# If you don't have ChiMera, you can Download via our [GitHub](https://github.com/tamascogustavo/chimera) or [PyPI](https://pypi.org/project/ChiMera-ModelBuilder/).
#
# Remember you need also to install [CPLEX](https://community.ibm.com/community/user/datascience/blogs/xavier-nodet1/2020/07/09/cplex-free-for-students). If you find problems during the installation, check our GitHub.
#
# ## Special thanks to
#
#
#  + Predefined maps generation by Escher
#
#     King, Z.A., Dräger, A., Ebrahim, A., Sonnenschein, N., Lewis, N.E. and Palsson, B.O., 2015. Escher: a web application for building, sharing, and embedding data-rich visualizations of biological pathways. PLoS computational biology, 11(8), p.e1004321.
#
# + Carving process by CarveMe
#
#     D. Machado et al, "Fast automated reconstruction of genome-scale metabolic models for microbial species and communities", Nucleic Acids Research, gky537, 2018. doi: https://doi.org/10.1093/nar/gky537
# + Model manipulation by Cobrapy
#
#     Ebrahim, A., Lerman, J.A., Palsson, B.O. and Hyduke, D.R., 2013. COBRApy: constraints-based reconstruction and analysis for python. BMC systems biology, 7(1), pp.1-6.
#
# + Generation of Cytoscape compatible maps with PSAMMr
#     Steffensen, J.L., Dufault-Thompson, K. and Zhang, Y., 2016. PSAMM: a portable system for the analysis of metabolic models. PLoS computational bio
#
# ## Don’t forget to cite them !!! And us as well 😃

# %% [markdown]
# # The basics of ChiMera

# %% [markdown]
# The command `python chimera_core.py -h` should prompt a short manual about ChiMera usage

# %%
! chimera_core.py -h
# Out:
# usage: chimera_core.py [-h] {core,silencing,harvest_path_cytoscape} ...
#
# positional arguments:
#   {core,silencing,harvest_path_cytoscape}
#     core                Runs the core module
#     silencing           Runs the knockout module
#     harvest_path_cytoscape
#                         Adds kegg pathway information to cytoscape maps
#
# optional arguments:
#   -h, --help            show this help message and exit

# %% [markdown]
# ## Here you can see all the modules of Chimera:
#
# To check the requirements of each of the modules, you can perform the same task again, just by adding the name of the module this time.
#
# The output will explain the requirements to perform the analysis.

# %%
! chimera_core.py core -h
# Out:
# usage: chimera_core.py core [-h] --organism ORGANISM --type TYPE --media MEDIA
#                             [--mediadb MEDIADB]
#
# optional arguments:
#   -h, --help           show this help message and exit
#   --organism ORGANISM  path to the *.faa file
#   --type TYPE          type of organism, options are gramneg, grampos,
#                        bacteria
#   --media MEDIA        Growth media ID
#   --mediadb MEDIADB    tsv file with a new media composition for new
#                        experimental conditions. If provided you must pass the
#                        media id in --media parameter.

# %%
! chimera_core.py silencing -h
# Out:
# usage: chimera_core.py silencing [-h] --i I --type TYPE --targets TARGETS
#                                  --faa FAA --mode MODE
#
# optional arguments:
#   -h, --help         show this help message and exit
#   --i I              path to the *.sbml model file
#   --type TYPE        type of knockout target, gene or reaction
#   --targets TARGETS  path to csv file containing targets, one by line
#   --faa FAA          path to the faa file
#   --mode MODE        Type of knockout: single or douple or all. For double all
#                      combinations of targets will be performed

# %%
! chimera_core.py harvest_path_cytoscape -h
# Out:
# usage: chimera_core.py harvest_path_cytoscape [-h] --table TABLE --model MODEL
#
# optional arguments:
#   -h, --help     show this help message and exit
#   --table TABLE  Path to reactions.edges.tsv file inside psam_* folder
#   --model MODEL  path to sbml model file

# %% [markdown]
# ## Let's us start with the CORE module

# %%
! chimera_core.py core --organism input_examples/faa_file/e_coli_test.faa --type gramneg --media M9
# Out:
# ---------------------------------------------------
# Building Model
# ---------------------------------------------------
# diamond v2.0.9.147 (C) Max Planck Society for the Advancement of Science
# Documentation, support and updates available at http://www.diamondsearch.org
# Please cite: http://dx.doi.org/10.1038/s41592-021-01101-x Nature Methods (2021)
#
# #CPU threads: 12
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# Temporary directory: input_examples/faa_file
# Percentage range of top alignment score to report hits: 10
# Opening the database...  [0.013s]
# Database: /Users/gustavotamasco/opt/anaconda3/lib/python3.7/site-packages/carveme/data/generated/bigg_proteins.dmnd (type: Diamond database, sequences: 26727, letters: 11170577)
# Block size = 2000000000
# Opening the input file...  [0.002s]
# Opening the output file...  [0s]
# Loading query sequences...  [0.011s]
# Masking queries...  [0.018s]
# Algorithm: Double-indexed
# Building query histograms...  [0.03s]
# Allocating buffers...  [0s]
# Loading reference sequences...  [0.013s]
# Masking reference...  [0.081s]
# Initializing temporary storage...  [0.001s]
# Building reference histograms...  [0.198s]
# Allocating buffers...  [0s]
# Processing query block 1, reference block 1/1, shape 1/16, index chunk 1/4.
# Building reference seed array...  [0.026s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.066s]
# Processing query block 1, reference block 1/1, shape 1/16, index chunk 2/4.
# Building reference seed array...  [0.037s]
# Building query seed array...  [0.007s]
# Computing hash join...  [0.007s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.039s]
# Processing query block 1, reference block 1/1, shape 1/16, index chunk 3/4.
# Building reference seed array...  [0.029s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.032s]
# Processing query block 1, reference block 1/1, shape 1/16, index chunk 4/4.
# Building reference seed array...  [0.019s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.032s]
# Processing query block 1, reference block 1/1, shape 2/16, index chunk 1/4.
# Building reference seed array...  [0.024s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.033s]
# Processing query block 1, reference block 1/1, shape 2/16, index chunk 2/4.
# Building reference seed array...  [0.025s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.032s]
# Processing query block 1, reference block 1/1, shape 2/16, index chunk 3/4.
# Building reference seed array...  [0.026s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.03s]
# Processing query block 1, reference block 1/1, shape 2/16, index chunk 4/4.
# Building reference seed array...  [0.021s]
# Building query seed array...  [0.002s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.03s]
# Processing query block 1, reference block 1/1, shape 3/16, index chunk 1/4.
# Building reference seed array...  [0.021s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.037s]
# Processing query block 1, reference block 1/1, shape 3/16, index chunk 2/4.
# Building reference seed array...  [0.028s]
# Building query seed array...  [0.005s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.036s]
# Processing query block 1, reference block 1/1, shape 3/16, index chunk 3/4.
# Building reference seed array...  [0.026s]
# Building query seed array...  [0.005s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.034s]
# Processing query block 1, reference block 1/1, shape 3/16, index chunk 4/4.
# Building reference seed array...  [0.022s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.034s]
# Processing query block 1, reference block 1/1, shape 4/16, index chunk 1/4.
# Building reference seed array...  [0.024s]
# Building query seed array...  [0.005s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.038s]
# Processing query block 1, reference block 1/1, shape 4/16, index chunk 2/4.
# Building reference seed array...  [0.029s]
# Building query seed array...  [0.005s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.038s]
# Processing query block 1, reference block 1/1, shape 4/16, index chunk 3/4.
# Building reference seed array...  [0.028s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.034s]
# Processing query block 1, reference block 1/1, shape 4/16, index chunk 4/4.
# Building reference seed array...  [0.021s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.031s]
# Processing query block 1, reference block 1/1, shape 5/16, index chunk 1/4.
# Building reference seed array...  [0.022s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.036s]
# Processing query block 1, reference block 1/1, shape 5/16, index chunk 2/4.
# Building reference seed array...  [0.025s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.032s]
# Processing query block 1, reference block 1/1, shape 5/16, index chunk 3/4.
# Building reference seed array...  [0.026s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.031s]
# Processing query block 1, reference block 1/1, shape 5/16, index chunk 4/4.
# Building reference seed array...  [0.023s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.032s]
# Processing query block 1, reference block 1/1, shape 6/16, index chunk 1/4.
# Building reference seed array...  [0.022s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.04s]
# Processing query block 1, reference block 1/1, shape 6/16, index chunk 2/4.
# Building reference seed array...  [0.026s]
# Building query seed array...  [0.005s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.035s]
# Processing query block 1, reference block 1/1, shape 6/16, index chunk 3/4.
# Building reference seed array...  [0.033s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.034s]
# Processing query block 1, reference block 1/1, shape 6/16, index chunk 4/4.
# Building reference seed array...  [0.025s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.035s]
# Processing query block 1, reference block 1/1, shape 7/16, index chunk 1/4.
# Building reference seed array...  [0.026s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.038s]
# Processing query block 1, reference block 1/1, shape 7/16, index chunk 2/4.
# Building reference seed array...  [0.026s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.033s]
# Processing query block 1, reference block 1/1, shape 7/16, index chunk 3/4.
# Building reference seed array...  [0.03s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.032s]
# Processing query block 1, reference block 1/1, shape 7/16, index chunk 4/4.
# Building reference seed array...  [0.022s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.031s]
# Processing query block 1, reference block 1/1, shape 8/16, index chunk 1/4.
# Building reference seed array...  [0.024s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.036s]
# Processing query block 1, reference block 1/1, shape 8/16, index chunk 2/4.
# Building reference seed array...  [0.029s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.034s]
# Processing query block 1, reference block 1/1, shape 8/16, index chunk 3/4.
# Building reference seed array...  [0.028s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.039s]
# Processing query block 1, reference block 1/1, shape 8/16, index chunk 4/4.
# Building reference seed array...  [0.029s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.036s]
# Processing query block 1, reference block 1/1, shape 9/16, index chunk 1/4.
# Building reference seed array...  [0.04s]
# Building query seed array...  [0.005s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.04s]
# Processing query block 1, reference block 1/1, shape 9/16, index chunk 2/4.
# Building reference seed array...  [0.027s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.035s]
# Processing query block 1, reference block 1/1, shape 9/16, index chunk 3/4.
# Building reference seed array...  [0.029s]
# Building query seed array...  [0.006s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.032s]
# Processing query block 1, reference block 1/1, shape 9/16, index chunk 4/4.
# Building reference seed array...  [0.021s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.001s]
# Searching alignments...  [0.032s]
# Processing query block 1, reference block 1/1, shape 10/16, index chunk 1/4.
# Building reference seed array...  [0.024s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.036s]
# Processing query block 1, reference block 1/1, shape 10/16, index chunk 2/4.
# Building reference seed array...  [0.027s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.033s]
# Processing query block 1, reference block 1/1, shape 10/16, index chunk 3/4.
# Building reference seed array...  [0.034s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.032s]
# Processing query block 1, reference block 1/1, shape 10/16, index chunk 4/4.
# Building reference seed array...  [0.024s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.032s]
# Processing query block 1, reference block 1/1, shape 11/16, index chunk 1/4.
# Building reference seed array...  [0.027s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.039s]
# Processing query block 1, reference block 1/1, shape 11/16, index chunk 2/4.
# Building reference seed array...  [0.025s]
# Building query seed array...  [0.006s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.034s]
# Processing query block 1, reference block 1/1, shape 11/16, index chunk 3/4.
# Building reference seed array...  [0.028s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.034s]
# Processing query block 1, reference block 1/1, shape 11/16, index chunk 4/4.
# Building reference seed array...  [0.025s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.003s]
# Searching alignments...  [0.034s]
# Processing query block 1, reference block 1/1, shape 12/16, index chunk 1/4.
# Building reference seed array...  [0.028s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.037s]
# Processing query block 1, reference block 1/1, shape 12/16, index chunk 2/4.
# Building reference seed array...  [0.03s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.035s]
# Processing query block 1, reference block 1/1, shape 12/16, index chunk 3/4.
# Building reference seed array...  [0.027s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.032s]
# Processing query block 1, reference block 1/1, shape 12/16, index chunk 4/4.
# Building reference seed array...  [0.023s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.033s]
# Processing query block 1, reference block 1/1, shape 13/16, index chunk 1/4.
# Building reference seed array...  [0.023s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.038s]
# Processing query block 1, reference block 1/1, shape 13/16, index chunk 2/4.
# Building reference seed array...  [0.027s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.034s]
# Processing query block 1, reference block 1/1, shape 13/16, index chunk 3/4.
# Building reference seed array...  [0.029s]
# Building query seed array...  [0.006s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.034s]
# Processing query block 1, reference block 1/1, shape 13/16, index chunk 4/4.
# Building reference seed array...  [0.024s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.003s]
# Searching alignments...  [0.032s]
# Processing query block 1, reference block 1/1, shape 14/16, index chunk 1/4.
# Building reference seed array...  [0.024s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.003s]
# Searching alignments...  [0.037s]
# Processing query block 1, reference block 1/1, shape 14/16, index chunk 2/4.
# Building reference seed array...  [0.026s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.034s]
# Processing query block 1, reference block 1/1, shape 14/16, index chunk 3/4.
# Building reference seed array...  [0.028s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.033s]
# Processing query block 1, reference block 1/1, shape 14/16, index chunk 4/4.
# Building reference seed array...  [0.023s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.032s]
# Processing query block 1, reference block 1/1, shape 15/16, index chunk 1/4.
# Building reference seed array...  [0.023s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.037s]
# Processing query block 1, reference block 1/1, shape 15/16, index chunk 2/4.
# Building reference seed array...  [0.026s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.003s]
# Searching alignments...  [0.035s]
# Processing query block 1, reference block 1/1, shape 15/16, index chunk 3/4.
# Building reference seed array...  [0.028s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.037s]
# Processing query block 1, reference block 1/1, shape 15/16, index chunk 4/4.
# Building reference seed array...  [0.028s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.034s]
# Processing query block 1, reference block 1/1, shape 16/16, index chunk 1/4.
# Building reference seed array...  [0.027s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.039s]
# Processing query block 1, reference block 1/1, shape 16/16, index chunk 2/4.
# Building reference seed array...  [0.031s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.004s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.035s]
# Processing query block 1, reference block 1/1, shape 16/16, index chunk 3/4.
# Building reference seed array...  [0.033s]
# Building query seed array...  [0.004s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.036s]
# Processing query block 1, reference block 1/1, shape 16/16, index chunk 4/4.
# Building reference seed array...  [0.023s]
# Building query seed array...  [0.003s]
# Computing hash join...  [0.005s]
# Building seed filter...  [0.002s]
# Searching alignments...  [0.032s]
# Deallocating buffers...  [0.001s]
# Clearing query masking...  [0s]
# Computing alignments...  [0.697s]
# Deallocating reference...  [0s]
# Loading reference sequences...  [0s]
# Deallocating buffers...  [0s]
# Deallocating queries...  [0s]
# Loading query sequences...  [0s]
# Closing the input file...  [0s]
# Closing the output file...  [0.002s]
# Closing the database file...  [0.002s]
# Deallocating taxonomy...  [0s]
# Total time = 5.832s
# Reported 9257 pairwise alignments, 9257 HSPs.
# 2275 queries aligned.
# Exit status: 0
# e_coli_test.sbml SBML model was created
# Basic info of the model
# -----------------------
# model has 2665 reactions
# model has 1668 metabolites
# model has 1702 genes
# The default flux bounds are:(-1000.0, 1000.0)
# Maximize
# 1.0*Growth - 1.0*Growth_reverse_699ae
# max
# objective expression 1.0*Growth - 1.0*Growth_reverse_699ae
# <Solution 0.674 at 0x7f91cad01d10>
# Objective
# =========
# 1.0 Growth = 0.674350736633079
#
# Uptake
# ------
#  Metabolite       Reaction      Flux  C-Number  C-Flux
#     M_ca2_e     R_EX_ca2_e   0.00351         0   0.00%
#      M_cl_e      R_EX_cl_e   0.00351         0   0.00%
# M_cobalt2_e R_EX_cobalt2_e 6.744E-05         0   0.00%
#     M_cu2_e     R_EX_cu2_e 0.0004781         0   0.00%
#     M_fe2_e     R_EX_fe2_e  0.004829         0   0.00%
#     M_fe3_e     R_EX_fe3_e  0.005265         0   0.00%
#  M_glc__D_e  R_EX_glc__D_e        10         6 100.00%
#       M_k_e       R_EX_k_e    0.1316         0   0.00%
#     M_mg2_e     R_EX_mg2_e   0.00585         0   0.00%
#     M_mn2_e     R_EX_mn2_e  0.000466         0   0.00%
#     M_nh4_e     R_EX_nh4_e     7.273         0   0.00%
#      M_o2_e      R_EX_o2_e        10         0   0.00%
#      M_pi_e      R_EX_pi_e    0.6501         0   0.00%
#     M_so4_e     R_EX_so4_e     0.169         0   0.00%
#     M_zn2_e     R_EX_zn2_e   0.00023         0   0.00%
#
# Secretion
# ---------
# Metabolite    Reaction       Flux  C-Number C-Flux
#   M_4hba_e R_EX_4hba_e -0.0001504         7  0.00%
#    M_co2_e  R_EX_co2_e      -18.4         1 56.92%
#   M_etoh_e R_EX_etoh_e     -6.964         2 43.08%
#    M_h2o_e  R_EX_h2o_e     -29.24         0  0.00%
#      M_h_e    R_EX_h_e     -6.201         0  0.00%
#
# e_coli_test.json was created.
# ---------------------------------------------------
# Generating Escher Metabolic Maps
# ---------------------------------------------------
# formatted_e_coli_test_tryptophan_metabolism.html was created
# formatted_e_coli_test_central_metabolism.html was created
# formatted_e_coli_test_carbohydrate_metabolism.html was created
# formatted_e_coli_test_central_carbon_metabolism_final.html was created
# formatted_e_coli_test_nucleotide_metabolism.html was created
# formatted_e_coli_test_fatty_acid_biosynthesis_saturated.html was created
# formatted_e_coli_test_fatty_acid_beta_oxidation.html was created
# formatted_e_coli_test_partial_amino_acid metabolism.html was created
# formatted_e_coli_test_glycolysis_TCA_PPP.html was created
# formatted_e_coli_test_inositol_retinol_metabolism.html was created
# <<< All escher maps are in : /Users/gustavotamasco/prometeus/gsmr/chimera/metabolism_maps>>>
# ---------------------------------------------------
# Creating Cytoscape Maps
# ---------------------------------------------------
# psamm_e_coli_test
# WARNING: Unable to parse charge for M_1agpg161_p as an integer: -1.0
# WARNING: Unable to parse charge for M_1p2cbxl_c as an integer: -1.0
# WARNING: Unable to parse charge for M_23ddhb_c as an integer: -1.0
# WARNING: Unable to parse charge for M_23dhbzs_c as an integer: -1.0
# WARNING: Unable to parse charge for M_2agpg120_c as an integer: -1.0
# WARNING: Unable to parse charge for M_2agpg120_p as an integer: -1.0
# WARNING: Unable to parse charge for M_2agpg180_c as an integer: -1.0
# WARNING: Unable to parse charge for M_2agpg180_p as an integer: -1.0
# WARNING: Unable to parse charge for M_2ahbut_c as an integer: -1.0
# WARNING: Unable to parse charge for M_2dr1p_c as an integer: -2.0
# WARNING: Unable to parse charge for M_2hdecg3p_c as an integer: -1.0
# WARNING: Unable to parse charge for M_2hdecg3p_p as an integer: -1.0
# WARNING: Unable to parse charge for M_2me4p_c as an integer: -2.0
# WARNING: Unable to parse charge for M_2shchc_c as an integer: -2.0
# WARNING: Unable to parse charge for M_3hocoa_c as an integer: -4.0
# WARNING: Unable to parse charge for M_3hodcoa_c as an integer: -4.0
# WARNING: Unable to parse charge for M_3uib_c as an integer: -1.0
# WARNING: Unable to parse charge for M_5aizc_c as an integer: -3.0
# WARNING: Unable to parse charge for M_5hiu_c as an integer: -1.0
# WARNING: Unable to parse charge for M_6p2dhglcn_c as an integer: 0.0
# WARNING: Unable to parse charge for M_6pgg_c as an integer: -2.0
# WARNING: Unable to parse charge for M_acgam1p_c as an integer: -2.0
# WARNING: Unable to parse charge for M_acgam1p_e as an integer: -2.0
# WARNING: Unable to parse charge for M_acgam1p_p as an integer: -2.0
# WARNING: Unable to parse charge for M_acmanap_c as an integer: -2.0
# WARNING: Unable to parse charge for M_acmum6p_c as an integer: -3.0
# WARNING: Unable to parse charge for M_air_c as an integer: -2.0
# WARNING: Unable to parse charge for M_anhgm3p_c as an integer: -2.0
# WARNING: Unable to parse charge for M_anhgm3p_p as an integer: -2.0
# WARNING: Unable to parse charge for M_argsuc_c as an integer: -1.0
# WARNING: Unable to parse charge for M_ascb__L_e as an integer: 0.0
# WARNING: Unable to parse charge for M_ascb__L_p as an integer: 0.0
# WARNING: Unable to parse charge for M_crncoa_c as an integer: -4.0
# WARNING: Unable to parse charge for M_ctbtcoa_c as an integer: -3.0
# WARNING: Unable to parse charge for M_db4p_c as an integer: -1.0
# WARNING: Unable to parse charge for M_dcamp_c as an integer: -4.0
# WARNING: Unable to parse charge for M_dhgly_c as an integer: -1.0
# WARNING: Unable to parse charge for M_dhpmp_c as an integer: -2.0
# WARNING: Unable to parse charge for M_dmlz_c as an integer: 1.0
# WARNING: Unable to parse charge for M_dscl_c as an integer: -7.0
# WARNING: Unable to parse charge for M_fadh2_c as an integer: 0.0
# WARNING: Unable to parse charge for M_fc1p_c as an integer: -2.0
# WARNING: Unable to parse charge for M_fdp_c as an integer: -4.0
# WARNING: Unable to parse charge for M_fe3dcit_c as an integer: -12.0
# WARNING: Unable to parse charge for M_fe3dcit_e as an integer: -12.0
# WARNING: Unable to parse charge for M_fe3dcit_p as an integer: -12.0
# WARNING: Unable to parse charge for M_fe3hox_un_c as an integer: -2.0
# WARNING: Unable to parse charge for M_fe3hox_un_e as an integer: -2.0
# WARNING: Unable to parse charge for M_fe3hox_un_p as an integer: -2.0
# WARNING: Unable to parse charge for M_feenter_c as an integer: -1.0
# WARNING: Unable to parse charge for M_feenter_e as an integer: -1.0
# WARNING: Unable to parse charge for M_feenter_p as an integer: -1.0
# WARNING: Unable to parse charge for M_feoxam_un_c as an integer: 1.0
# WARNING: Unable to parse charge for M_feoxam_un_e as an integer: 1.0
# WARNING: Unable to parse charge for M_feoxam_un_p as an integer: 1.0
# WARNING: Unable to parse charge for M_fgam_c as an integer: -2.0
# WARNING: Unable to parse charge for M_fmnh2_c as an integer: 0.0
# WARNING: Unable to parse charge for M_fpram_c as an integer: -2.0
# WARNING: Unable to parse charge for M_frulysp_c as an integer: -1.0
# WARNING: Unable to parse charge for M_fruur_c as an integer: -1.0
# WARNING: Unable to parse charge for M_fruur_e as an integer: -1.0
# WARNING: Unable to parse charge for M_fruur_p as an integer: -1.0
# WARNING: Unable to parse charge for M_g3p_c as an integer: -2.0
# WARNING: Unable to parse charge for M_g3pg_c as an integer: -1.0
# WARNING: Unable to parse charge for M_g3pg_e as an integer: -1.0
# WARNING: Unable to parse charge for M_g3pg_p as an integer: -1.0
# WARNING: Unable to parse charge for M_gdptp_c as an integer: -7.0
# WARNING: Unable to parse charge for M_glcur1p_e as an integer: -3.0
# WARNING: Unable to parse charge for M_glcur1p_p as an integer: -3.0
# WARNING: Unable to parse charge for M_h2s_c as an integer: 0.0
# WARNING: Unable to parse charge for M_h2s_e as an integer: 0.0
# WARNING: Unable to parse charge for M_h2s_p as an integer: 0.0
# WARNING: Unable to parse charge for M_hkntd_c as an integer: -2.0
# WARNING: Unable to parse charge for M_man1p_c as an integer: -2.0
# WARNING: Unable to parse charge for M_man6p_c as an integer: -2.0
# WARNING: Unable to parse charge for M_man6p_e as an integer: -2.0
# WARNING: Unable to parse charge for M_man6p_p as an integer: -2.0
# WARNING: Unable to parse charge for M_man6pglyc_c as an integer: -3.0
# WARNING: Unable to parse charge for M_murein3px3p_p as an integer: -4.0
# WARNING: Unable to parse charge for M_murein4px4p_p as an integer: -4.0
# WARNING: Unable to parse charge for M_murein5px4p_p as an integer: -4.0
# WARNING: Unable to parse charge for M_murein5px4px4p_p as an integer: -6.0
# WARNING: Unable to parse charge for M_n2o_c as an integer: -2.0
# WARNING: Unable to parse charge for M_n2o_e as an integer: -2.0
# WARNING: Unable to parse charge for M_n2o_p as an integer: -2.0
# WARNING: Unable to parse charge for M_oc2coa_c as an integer: -4.0
# WARNING: Unable to parse charge for M_op4en_c as an integer: -1.0
# WARNING: Unable to parse charge for M_pa120_c as an integer: -2.0
# WARNING: Unable to parse charge for M_pa120_p as an integer: -2.0
# WARNING: Unable to parse charge for M_pa140_c as an integer: -2.0
# WARNING: Unable to parse charge for M_pa140_p as an integer: -2.0
# WARNING: Unable to parse charge for M_pa141_c as an integer: -2.0
# WARNING: Unable to parse charge for M_pa141_p as an integer: -2.0
# WARNING: Unable to parse charge for M_pa161_c as an integer: -2.0
# WARNING: Unable to parse charge for M_pa161_p as an integer: -2.0
# WARNING: Unable to parse charge for M_pa180_c as an integer: -2.0
# WARNING: Unable to parse charge for M_pa180_p as an integer: -2.0
# WARNING: Unable to parse charge for M_pa181_c as an integer: -2.0
# WARNING: Unable to parse charge for M_pa181_p as an integer: -2.0
# WARNING: Unable to parse charge for M_pg120_c as an integer: -1.0
# WARNING: Unable to parse charge for M_pg120_p as an integer: -1.0
# WARNING: Unable to parse charge for M_pg160_c as an integer: -1.0
# WARNING: Unable to parse charge for M_pg160_p as an integer: -1.0
# WARNING: Unable to parse charge for M_pg180_c as an integer: -1.0
# WARNING: Unable to parse charge for M_pg180_p as an integer: -1.0
# WARNING: Unable to parse charge for M_pgp120_c as an integer: -3.0
# WARNING: Unable to parse charge for M_pgp120_p as an integer: -3.0
# WARNING: Unable to parse charge for M_pgp140_c as an integer: -3.0
# WARNING: Unable to parse charge for M_pgp140_p as an integer: -3.0
# WARNING: Unable to parse charge for M_pgp141_c as an integer: -3.0
# WARNING: Unable to parse charge for M_pgp141_p as an integer: -3.0
# WARNING: Unable to parse charge for M_pgp160_c as an integer: -3.0
# WARNING: Unable to parse charge for M_pgp160_p as an integer: -3.0
# WARNING: Unable to parse charge for M_pgp161_c as an integer: -3.0
# WARNING: Unable to parse charge for M_pgp161_p as an integer: -3.0
# WARNING: Unable to parse charge for M_pgp180_c as an integer: -3.0
# WARNING: Unable to parse charge for M_pgp180_p as an integer: -3.0
# WARNING: Unable to parse charge for M_pgp181_c as an integer: -3.0
# WARNING: Unable to parse charge for M_pgp181_p as an integer: -3.0
# WARNING: Unable to parse charge for M_ppgpp_c as an integer: -6.0
# WARNING: Unable to parse charge for M_pphn_c as an integer: -2.0
# WARNING: Unable to parse charge for M_pppi_c as an integer: -4.0
# WARNING: Unable to parse charge for M_pprdn_c as an integer: 0.0
# WARNING: Unable to parse charge for M_pqq_p as an integer: -4.0
# WARNING: Unable to parse charge for M_prbamp_c as an integer: -4.0
# WARNING: Unable to parse charge for M_prbatp_c as an integer: -6.0
# WARNING: Unable to parse charge for M_ps160_c as an integer: -1.0
# WARNING: Unable to parse charge for M_ps161_c as an integer: -1.0
# WARNING: Unable to parse charge for M_ps181_c as an integer: -1.0
# WARNING: Unable to parse charge for M_r5p_c as an integer: -2.0
# WARNING: Unable to parse charge for M_r5p_e as an integer: -2.0
# WARNING: Unable to parse charge for M_r5p_p as an integer: -2.0
# WARNING: Unable to parse charge for M_rbflvrd_c as an integer: 2.0
# WARNING: Unable to parse charge for M_ribflv_c as an integer: 2.0
# WARNING: Unable to parse charge for M_ribflv_e as an integer: 2.0
# WARNING: Unable to parse charge for M_rml1p_c as an integer: -2.0
# WARNING: Unable to parse charge for M_sbt6p_c as an integer: -2.0
# WARNING: Unable to parse charge for M_sbzcoa_c as an integer: -5.0
# WARNING: Unable to parse charge for M_scl_c as an integer: -7.0
# WARNING: Unable to parse charge for M_seramp_c as an integer: -1.0
# WARNING: Unable to parse charge for M_ssaltpp_c as an integer: -4.0
# WARNING: Unable to parse charge for M_suc6p_c as an integer: -2.0
# WARNING: Unable to parse charge for M_tag6p__D_c as an integer: -3.0
# WARNING: Unable to parse charge for M_tagdp__D_c as an integer: -4.0
# WARNING: Unable to parse charge for M_tagur_c as an integer: -1.0
# WARNING: Unable to parse charge for M_td2coa_c as an integer: -4.0
# WARNING: Unable to parse charge for M_tdecoa_c as an integer: -4.0
# WARNING: Unable to parse charge for M_tgt_e as an integer: -3.0
# WARNING: Unable to parse charge for M_tsul_c as an integer: -2.0
# WARNING: Unable to parse charge for M_tsul_e as an integer: -2.0
# WARNING: Unable to parse charge for M_tsul_p as an integer: -2.0
# WARNING: Unable to parse charge for M_tton_e as an integer: 0.0
# WARNING: Unable to parse charge for M_uaagmda_c as an integer: -3.0
# WARNING: Unable to parse charge for M_uagmda_c as an integer: -3.0
# WARNING: Unable to parse charge for M_uamr_c as an integer: -3.0
# WARNING: Unable to parse charge for M_udcpdp_c as an integer: -2.0
# WARNING: Unable to parse charge for M_udpacgal_e as an integer: -2.0
# WARNING: Unable to parse charge for M_udpacgal_p as an integer: -2.0
# INFO: e is extracellular compartment
# Model: None
# - Biomass reaction: Growth
# - Compartments: 3
# - Compounds: 1668
# - Reactions: 2319
# - Genes: 0
# INFO: Using default flux limit of 1000
# INFO: Converting exchange reactions to exchange file
# Exit status: 0
# psamm_e_coli_test was created
# INFO:numexpr.utils:Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO: Model version: b'54c3428-dirty'
# WARNING: The compound cd2_e was in the extracellular compartment but not defined in the exchange compounds
# WARNING: The compound cm_e was in the extracellular compartment but not defined in the exchange compounds
# WARNING: The compound cro4_e was in the extracellular compartment but not defined in the exchange compounds
# WARNING: The compound doxrbcn_e was in the extracellular compartment but not defined in the exchange compounds
# WARNING: The compound fusa_e was in the extracellular compartment but not defined in the exchange compounds
# WARNING: The compound gbbtn_e was in the extracellular compartment but not defined in the exchange compounds
# WARNING: The compound hg2_e was in the extracellular compartment but not defined in the exchange compounds
# WARNING: The compound na1_e was in the extracellular compartment but not defined in the exchange compounds
# WARNING: The compound ni2_e was in the extracellular compartment but not defined in the exchange compounds
# WARNING: The compound novbcn_e was in the extracellular compartment but not defined in the exchange compounds
# WARNING: The compound ttrcyc_e was in the extracellular compartment but not defined in the exchange compounds
# WARNING: Reaction Growth is in the subset and exclude file. Reaction will be excluded.
# INFO: Iteration 1: 2314 reactions...
# INFO: Iteration 2: 2314 reactions...
# INFO: Iteration 3: 950 reactions...
# INFO: Iteration 4: 20 reactions...
# The status is 0
# The .tsv files for cytoscape were generated
# Harvesting metabolic pathways from model. This may take a while...
# (get_compound_info pid=37636) /Users/gustavotamasco/opt/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:439: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
# (get_compound_info pid=37636)   MarkupResemblesLocatorWarning

# %% [markdown]
# ***As you can see, a lot of data is produced.***
#
# ### Let's go over the results:
#
# First, we can see that a model is created and loaded into Cobrapy. There we perform FBA using the defined biomass equation.
#
# ```
# e_coli_test.sbml SBML model was created
# Basic info of the model
# -----------------------
# model has 2665 reactions
# model has 1668 metabolites
# model has 1702 genes
#
# ```
#
# Next is prompted to the user the table of predicted growth rate and fluxes.
# Don't worry, we also save the output in a CSV file, so you can check the data later (the extension is `_uptake_secretion_rates.csv`).
#
# ```
#
# <Solution 0.674 at 0x7f91cad01d10>
# Objective
# =========
# 1.0 Growth = 0.674350736633079
#
# Uptake
# ------
#  Metabolite       Reaction      Flux  C-Number  C-Flux
#     M_ca2_e     R_EX_ca2_e   0.00351         0   0.00%
#      M_cl_e      R_EX_cl_e   0.00351         0   0.00%
# M_cobalt2_e R_EX_cobalt2_e 6.744E-05         0   0.00%
#     M_cu2_e     R_EX_cu2_e 0.0004781         0   0.00%
#     M_fe2_e     R_EX_fe2_e  0.004829         0   0.00%
#     M_fe3_e     R_EX_fe3_e  0.005265         0   0.00%
#  M_glc__D_e  R_EX_glc__D_e        10         6 100.00%
#       M_k_e       R_EX_k_e    0.1316         0   0.00%
#     M_mg2_e     R_EX_mg2_e   0.00585         0   0.00%
#     M_mn2_e     R_EX_mn2_e  0.000466         0   0.00%
#     M_nh4_e     R_EX_nh4_e     7.273         0   0.00%
#      M_o2_e      R_EX_o2_e        10         0   0.00%
#      M_pi_e      R_EX_pi_e    0.6501         0   0.00%
#     M_so4_e     R_EX_so4_e     0.169         0   0.00%
#     M_zn2_e     R_EX_zn2_e   0.00023         0   0.00%
#
# Secretion
# ---------
# Metabolite    Reaction       Flux  C-Number C-Flux
#   M_4hba_e R_EX_4hba_e -0.0001504         7  0.00%
#    M_co2_e  R_EX_co2_e      -18.4         1 56.92%
#   M_etoh_e R_EX_etoh_e     -6.964         2 43.08%
#    M_h2o_e  R_EX_h2o_e     -29.24         0  0.00%
#      M_h_e    R_EX_h_e     -6.201         0  0.00%
#
# ```
#
# Next, we convert the model to different formats, allowing users to load the produced model in different software.
#
# We also use the model to perform metabolic pathway detection. The results are located in the folder **metabolism_maps**.  There you will find the maps of the most important pathways. Data in blue indicates presence in your model. Red indicates absence.
#
# Inside the **psamm folder**, you will find YAML files, explaining the model composition. With them, you can check the reactions, compounds, and more. The `reactions.edges` and `reactions.nodes` are compatible with Gephi and Cytoscape, so you can load your graphs in this software to visualize you model. In our GitHub, you have links explaining how to do that.
#
# We also produce a CSV file that contains the `enriched detected pathways` in your model. We use KEGG API for that. The same file is used to produce an `HTML interactive image` of the 30 most detected pathways.
#
#
# ![ChiMera Paths](input_examples/assets/chimera_paths.png "Top 30 detected Pathways")

# %%
import pandas as pd

# %%
reactions = pd.read_csv("input_examples/treasure_chest/e_coli_test_enriched_paths.csv")
reactions.head(10)
# Out:
#                                              Pathway  Counts
# 0          map00051  Fructose and mannose metabolism      17
# 1                       map01100  Metabolic pathways     321
# 2                         map02010  ABC transporters      43
# 3          map02060  Phosphotransferase system (PTS)      21
# 4       map00270  Cysteine and methionine metabolism      18
# 5                map00670  One carbon pool by folate       3
# 6  map00720  Carbon fixation pathways in prokaryotes      19
# 7              map00970  Aminoacyl-tRNA biosynthesis      14
# 8  map01120  Microbial metabolism in diverse envi...     109
# 9                        map01200  Carbon metabolism      43

# %% [markdown]
# ## The hasvest module

# %%
! chimera_core.py harvest_path_cytoscape --table input_examples/treasure_chest/psamm_e_coli_test/reactions.edges.tsv  --model input_examples/treasure_chest/e_coli_test.sbml
# Out:
# Process initiated, this can take some time!
# 735

# %% [markdown]
# The command will create a new `reactions_edges.tsv` file inside the main folder. This file now have information about the pathways that the compounds participate.
#
# ### Let's take a look

# %%
df = pd.read_table("input_examples/treasure_chest/e_coli_test_reactions_edges.tsv")
df.head(10)
# Out:
#           source       target direction penwidth  style       source_pathway  \
# 0    10fthf_c[c]      GARFT_1      both        1  solid  no pathway detected
# 1        GARFT_1    fgam_c[c]      both        1  solid  no pathway detected
# 2    10fthf_c[c]      FTHFD_1   forward        1  solid  no pathway detected
# 3        FTHFD_1     for_c[c]   forward        1  solid  no pathway detected
# 4    10fthf_c[c]     AICART_1      both        1  solid  no pathway detected
# 5       AICART_1  fprica_c[c]      both        1  solid  no pathway detected
# 6       AICART_1     thf_c[c]      both        1  solid  no pathway detected
# 7        GARFT_1     thf_c[c]      both        1  solid  no pathway detected
# 8        FTHFD_1     thf_c[c]   forward        1  solid  no pathway detected
# 9  12dgr120_c[c]    DAGK120_1   forward        1  solid  no pathway detected
#
#                                       target_pathway
# 0                                no pathway detected
# 1  map00230  Purine metabolism | map01100  Metabo...
# 2                                no pathway detected
# 3                                no pathway detected
# 4                                no pathway detected
# 5  map00230  Purine metabolism | map01060  Biosyn...
# 6                                no pathway detected
# 7                                no pathway detected
# 8                                no pathway detected
# 9                                no pathway detected

# %% [markdown]
# ## Finally we have the knockout module

# %% [markdown]
# The logic that we will show here is the same for all the possible combinations of parameters.
#
# First, we will perform an example of a single gene, after which we will make a double reaction knockout.

# %% [markdown]
# ### Single gene

# %%
! chimera_core.py silencing --i input_examples/treasure_chest/e_coli_test.sbml --type gene --targets input_examples/reations_gene_to_delete/knockout_genes_list.txt --faa input_examples/faa_file/e_coli_test.faa --mode single
# Out:
# complete model growth rate:  <Solution 0.674 at 0x7fb9adcda810>
#
#
# The knockout effect of trkA
#                                              ids    growth   status
# 282  {lcl_NZ_CP027599_1_prot_WP_000691382_1_476}  0.674351  optimal
#
#
# The knockout effect of gltP
#                                               ids    growth   status
# 365  {lcl_NZ_CP027599_1_prot_WP_000835799_1_5587}  0.674351  optimal
#
#
# The knockout effect of cysQ
#                                                ids    growth   status
# 1654  {lcl_NZ_CP027599_1_prot_WP_000886909_1_5394}  0.674351  optimal
#
#
# The knockout effect of argC
#                                                ids  growth   status
# 1275  {lcl_NZ_CP027599_1_prot_WP_000935363_1_5705}     0.0  optimal
#
#
# The knockout effect of pgpA
#                                               ids    growth   status
# 852  {lcl_NZ_CP027599_1_prot_WP_000154044_1_4715}  0.674351  optimal
#
#
# The knockout effect of edd
#                                               ids    growth   status
# 334  {lcl_NZ_CP027599_1_prot_WP_001069467_1_2511}  0.674351  optimal
#
#
# The knockout effect of dctA
#                                               ids    growth   status
# 1074  {lcl_NZ_CP027599_1_prot_WP_044164517_1_245}  0.674351  optimal
#
#
# The knockout effect of ddlB
#                                               ids    growth   status
# 651  {lcl_NZ_CP027599_1_prot_WP_000130056_1_5076}  0.674351  optimal
#
#
# The knockout effect of thrC
#                                                ids  growth   status
# 1391  {lcl_NZ_CP027599_1_prot_WP_000781063_1_5168}     0.0  optimal
#
#
# The knockout effect of map
#                                                ids    growth   status
# 1025  {lcl_NZ_CP027599_1_prot_WP_001018204_1_4999}  0.674351  optimal
#
#
# The knockout effect of relA
#                                                ids    growth   status
# 1342  {lcl_NZ_CP027599_1_prot_WP_000226815_1_1095}  0.674351  optimal
#
#
# The knockout effect of pyrF
#                                               ids  growth   status
# 447  {lcl_NZ_CP027599_1_prot_WP_000176278_1_2958}     0.0  optimal
#
#
# The knockout effect of pyrD
#                                                ids    growth   status
# 1083  {lcl_NZ_CP027599_1_prot_WP_001295352_1_4084}  0.671667  optimal

# %% [markdown]
# ### Double reaction

# %%
! chimera_core.py silencing --i input_examples/treasure_chest/e_coli_test.sbml --type reaction --targets input_examples/reations_gene_to_delete/knockout_reactions_list.txt --faa input_examples/faa_file/e_coli_test.faa --mode double
# Out:
# complete model growth rate:  <Solution 0.674 at 0x7fbb8be87ed0>
#
#
# The knockout effect of GLCDpp + HEX1
# <Solution 0.674 at 0x7fbb8be87bd0>
#
#
# The knockout effect of GLCDpp + GNK
# <Solution 0.674 at 0x7fbb8be87b10>
#
#
# The knockout effect of GLCDpp + PGLCNDH
# <Solution 0.674 at 0x7fbb8be87e10>
#
#
# The knockout effect of GLCDpp + EDD
# <Solution 0.674 at 0x7fbb8be87a10>
#
#
# The knockout effect of GLCDpp + EDA
# <Solution 0.674 at 0x7fbb8be87dd0>
#
#
# The knockout effect of HEX1 + GNK
# <Solution 0.674 at 0x7fbb8be87e90>
#
#
# The knockout effect of HEX1 + PGLCNDH
# <Solution 0.674 at 0x7fbb8be87b10>
#
#
# The knockout effect of HEX1 + EDD
# <Solution 0.674 at 0x7fbb8be87d90>
#
#
# The knockout effect of HEX1 + EDA
# <Solution 0.674 at 0x7fbb8be87f10>
#
#
# The knockout effect of GNK + PGLCNDH
# <Solution 0.674 at 0x7fbb8be87890>
#
#
# The knockout effect of GNK + EDD
# <Solution 0.674 at 0x7fbb8be87a10>
#
#
# The knockout effect of GNK + EDA
# <Solution 0.674 at 0x7fbb8be87950>
#
#
# The knockout effect of PGLCNDH + EDD
# <Solution 0.674 at 0x7fbb8be87b10>
#
#
# The knockout effect of PGLCNDH + EDA
# <Solution 0.674 at 0x7fbb8be87d90>
#
#
# The knockout effect of EDD + EDA
# <Solution 0.674 at 0x7fbb8be873d0>

# %% [markdown]
# # Finish
#
# I believe that's it! With this tutorial, you can start building your own GSMR.
#
# If you have any issues, please let me know via [GitHub](https://github.com/tamascogustavo/chimera) or contact me via *tamascogustavo@gmail.com*
#
#
# Oh ! **Don't forget to cite us and the others** ✌️
